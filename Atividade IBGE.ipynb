# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from io import StringIO
from google.colab import files

uploaded = files.upload()

sb.set(rc={'figure.figsize':(15,5)})


filename = list(uploaded.keys())[0]
file_content = uploaded[filename]
ibge = pd.read_csv(StringIO(file_content.decode('utf-8')), delimiter=';')
ibge.head(20)
# Out:
#      <input type="file" id="files-c64fbb22-db40-45ec-8f01-3bc676e78051" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c64fbb22-db40-45ec-8f01-3bc676e78051">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Organização            422 non-null    object
#  1   Nome                   422 non-null    object
#  2   Descrição              422 non-null    object
#  3   Tags                   417 non-null    object
#  4   Quantidade Recursos    422 non-null    int64
#  5   Quantidade Reusos      422 non-null    int64
#  6   Quantidade Downloads   422 non-null    int64
#  7   Quantidade Seguidores  422 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 26.5+ KB

# %%
print(ibge.describe())
# Out:
#        Quantidade Recursos  Quantidade Reusos  Quantidade Downloads  \
# count           422.000000              422.0            422.000000
# mean              5.563981                0.0            101.736967
# std               5.054048                0.0            356.247611
# min               1.000000                0.0              0.000000
# 25%               5.000000                0.0              2.000000
# 50%               5.000000                0.0              7.000000
# 75%               5.000000                0.0             46.750000
# max              75.000000                0.0           3601.000000
#
#        Quantidade Seguidores
# count             422.000000
# mean                0.106635
# std                 0.487861
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 5.000000

# %%
# Descobrir valores únicos de uma coluna
print(ibge['Quantidade Recursos'].unique())

# Contar a frequência de valores em uma coluna
print(ibge['Quantidade Recursos'].value_counts())
# Out:
# [36  9 45  2 18 75  5 55  6  4 17  1 28  8]
# Quantidade Recursos
# 5     406
# 9       2
# 4       2
# 1       2
# 36      1
# 45      1
# 2       1
# 18      1
# 75      1
# 55      1
# 6       1
# 17      1
# 28      1
# 8       1
# Name: count, dtype: int64

# %%
# Verificar valores vazios
print(ibge.isnull().sum())
# Out:
# Organização              0
# Nome                     0
# Descrição                0
# Tags                     5
# Quantidade Recursos      0
# Quantidade Reusos        0
# Quantidade Downloads     0
# Quantidade Seguidores    0
# dtype: int64

# %%
colunas_desejadas = ibge[['Quantidade Downloads', 'Quantidade Recursos']]
print('\nDados das colunas Quantidade Downloads e Quantidade Recursos:')
print(colunas_desejadas)
# Out:
# Dados das colunas Quantidade Downloads e Quantidade Recursos:
#      Quantidade Downloads  Quantidade Recursos
# 0                    2201                   36
# 1                    1139                    9
# 2                    1130                   45
# 3                    2036                    2
# 4                    3011                   18
# ..                    ...                  ...
# 417                   691                    5
# 418                  3601                    8
# 419                   453                    5
# 420                   447                    5
# 421                  2257                    5
#
# [422 rows x 2 columns]

# %%
# Consulta a uma linha específica

indice = 3
linha_desejada = ibge.iloc[indice]

print('\nDados da linha', indice, ':')
print(linha_desejada)
# Out:
# Dados da linha 3 :
# Organização              Instituto Brasileiro de Geografia e Estatístic...
# Nome                                           Indicadores sobre População
# Descrição                Série histórica de indicadores dos resultados ...
# Tags                                                         Indicador,PGI
# Quantidade Recursos                                                      2
# Quantidade Reusos                                                        0
# Quantidade Downloads                                                  2036
# Quantidade Seguidores                                                    2
# Name: 3, dtype: object

# %%
# Acesso a uma linha e coluna específica
linha_indice = 2
coluna_nome = 'Quantidade Seguidores'
celula_desejada = ibge.loc[linha_indice, coluna_nome]
print('\nDado na Linha: ', linha_indice, 'Dado na coluna:', coluna_nome, ':')
print(celula_desejada)
# Out:
# Dado na Linha:  2 Dado na coluna: Quantidade Seguidores :
# 1

# %%
# Graficos histograma
colunas_desejadas = ibge[['Quantidade Downloads', 'Quantidade Recursos']]
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(colunas_desejadas['Quantidade Downloads'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Distribuição de Downloads')
plt.xlabel('Quantidade Downloads')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
plt.subplot(1, 2, 1)
plt.hist(colunas_desejadas['Quantidade Recursos'].dropna(), bins=20, color='salmon', edgecolor='black')
plt.title('Distribuição de recursos')
plt.xlabel('Quantidade recursos')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')
